# %%
from os import walk, path, name as osname
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
RAW_DATA = './data/raw'
TRAIN_DATA = './data/train'
TEST_DATA = './data/test'
TEST_SIZE = 0.3

# %%
from subprocess import Popen, PIPE, STDOUT
from IPython.core.magic import register_line_magic

@register_line_magic
def runshell(command):
    with Popen(
        command, stdout=PIPE, shell=True, stderr=STDOUT, bufsize=1, close_fds=True
    ) as process:
        for line in iter(process.stdout.readline, b""):
            print(line.decode("utf-8"), end='')

# %%
# Convert this cell to 'Code' to build mltextclassifier.exe
if osname == 'nt':
    # %runshell cd ..\.. && mkdir build && cd build && cmake .. >> buildlog.txt 2>&1
    # %runshell cd ..\..\build && cmake --build . --config Release >> buildlog.txt 2>&1
    # %runshell copy ..\..\build\Release\mltextclassifier.exe .

    MLTEXTCLASSIFIER = "mltextclassifier.exe"
else:
    # %runshell cd ../.. && mkdir build && cd build && cmake .. >> buildlog.txt 2>&1
    # %runshell cd ../../build && cmake --build . --config Release >> buildlog.txt 2>&1
    # %runshell cp ../../build/mltextclassifier .

    MLTEXTCLASSIFIER = "./mltextclassifier"
# Out:
# c:\users\rajas\appdata\local\programs\python\python39\lib\subprocess.py:937: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# A subdirectory or file build already exists.
#         1 file(s) copied.

# %%
#https://www.kaggle.com/datasets/abhi8923shriv/sentiment-analysis-dataset?select=train.csv renamed as data.csv in raw/
with open(RAW_DATA + '/data.csv', errors='ignore') as f:
    df = pd.read_csv(f)

# %%
df = df[df.sentiment != 'neutral'][['text', 'sentiment']]

# %%
df['sentiment'] = df['sentiment'].replace({'positive': 1, 'negative': 0})

# %%
df = df.sample(frac=1)
df
# Out:
#                                                     text  sentiment
# 24455   yearling in pet home died... very sad for the...          0
# 4488   is excited to see Samantha&Denise again  http:...          1
# 26430  Located & ordered a new cooker today. Feel I`v...          1
# 20403   remember the guy who 1st #tweetbud you! ~> _2...          1
# 9423   Goodnight twitterworld. I`ll tweet y`all later...          1
# ...                                                  ...        ...
# 8661    Its goin good takin it easy ths weekend  Im p...          1
# 7876   Playing with the munchkin today, talking cakes...          0
# 22301   - I will help  not sure how when i`m alllll t...          1
# 17103               Chillin` following some cool people!          1
# 18810  Day 8 of the 30 Day Shred and Day 5 of Special...          1
#
# [16363 rows x 2 columns]

# %%
text_0 = ' '.join(df.loc[df.sentiment == 0]['text'])
text_1 = ' '.join(df.loc[df.sentiment == 1]['text'])

wordcloud_0 = WordCloud().generate(text_0)
wordcloud_1 = WordCloud().generate(text_1)

fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,6))

ax1.imshow(wordcloud_0)
ax1.axis("off")
ax1.set_title("Wordcloud for label 0",fontsize=20)

ax2.imshow(wordcloud_1)
ax2.axis("off")
ax2.set_title("Wordcloud for label 1",fontsize=20)

plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], stratify=df['sentiment'], 
                                                    test_size=TEST_SIZE, random_state=42)

df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_train.shape[0], df_test.shape[0]
# Out:
# (11454, 4909)

# %%
def save_data(df, rootdir):
    with open(rootdir + '/features.txt', 'wt', errors='ignore') as feat_fh, \
        open(rootdir + '/labels.txt', 'wt', errors='ignore') as labl_fh:
        for idx, row in df.iterrows():
            lb = str(row['sentiment']) + '\n'
            ft = row['text'].lower() + '\n'
            labl_fh.write(lb)
            feat_fh.write(ft)

# %%
save_data(df_train, TRAIN_DATA)
save_data(df_test, TEST_DATA)
df_test.to_csv(TEST_DATA + '/data_test.csv', index=False)

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 1 {path.join('model','model_CounterVectorizer_NaiveBayesClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 smoothing_param_m=1.0,smoothing_param_p=0.5
# Out:
# c:\users\rajas\appdata\local\programs\python\python39\lib\subprocess.py:937: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# Training
# minfrequency = 2
# smoothing_param_m = 1
# smoothing_param_p = 0.5
# No of Rare Words = 15010
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 0 ns
# Wall time: 534 ms

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 1 {path.join('model','model_TfidfVectorizer_NaiveBayesClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 smoothing_param_m=1.0,smoothing_param_p=0.5
# Out:
# Training
# minfrequency = 2
# smoothing_param_m = 1
# smoothing_param_p = 0.5
# No of Rare Words = 15010
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 0 ns
# Wall time: 2.56 s

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 2 {path.join('model','model_CounterVectorizer_LogisticRegressionClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15010
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# Epoch 0 Loss: 0.574126
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 4 s

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 2 {path.join('model','model_TfidfVectorizer_LogisticRegressionClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15010
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# Epoch 0 Loss: 0.41608
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 6.32 s

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 3 {path.join('model','model_CounterVectorizer_SVCClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15010
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 0 ns
# Wall time: 3.89 s

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 3 {path.join('model','model_TfidfVectorizer_SVCClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15010
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 6.28 s

# %% [raw]
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 4 {path.join('model','model_CounterVectorizer_KNNClassifier.dat')} {path.join('data','train','features.txt')} 1.0 k=3

# %% [raw]
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 4 {path.join('model','model_TfidfVectorizer_KNNClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 k=3

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 5 {path.join('model','model_CounterVectorizer_RandomForestClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 num_trees=50,max_depth=5
# Out:
# Training
# minfrequency = 2
# num_trees = 50
# max_depth = 5
# No of Rare Words = 15010
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 1.28 s

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 5 {path.join('model','model_TfidfVectorizer_RandomForestClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 num_trees=50,max_depth=5
# Out:
# Training
# minfrequency = 2
# num_trees = 50
# max_depth = 5
# No of Rare Words = 15010
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 0 ns
# Wall time: 4.18 s

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 6 {path.join('model','model_CounterVectorizer_GradientBoostingClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15010
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 3.63 s

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 6 {path.join('model','model_TfidfVectorizer_GradientBoostingClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15010
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6668
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 5.78 s
