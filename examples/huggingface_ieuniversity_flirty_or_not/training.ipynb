# %%
from os import walk, path, name as osname
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
RAW_DATA = './data/raw'
TRAIN_DATA = './data/train'
TEST_DATA = './data/test'
TEST_SIZE = 0.3

# %%
from subprocess import Popen, PIPE, STDOUT
from IPython.core.magic import register_line_magic

@register_line_magic
def runshell(command):
    with Popen(
        command, stdout=PIPE, shell=True, stderr=STDOUT, bufsize=1, close_fds=True
    ) as process:
        for line in iter(process.stdout.readline, b""):
            print(line.decode("utf-8"), end='')

# %%
# Convert this cell to 'Code' to build mltextclassifier.exe
if osname == 'nt':
    # %runshell cd ..\.. && mkdir build && cd build && cmake .. >> buildlog.txt 2>&1
    # %runshell cd ..\..\build && cmake --build . --config Release >> buildlog.txt 2>&1
    # %runshell copy ..\..\build\Release\mltextclassifier.exe .

    MLTEXTCLASSIFIER = "mltextclassifier.exe"
else:
    # %runshell cd ../.. && mkdir build && cd build && cmake .. >> buildlog.txt 2>&1
    # %runshell cd ../../build && cmake --build . --config Release >> buildlog.txt 2>&1
    # %runshell cp ../../build/mltextclassifier .

    MLTEXTCLASSIFIER = "./mltextclassifier"
# Out:
# c:\users\rajas\appdata\local\programs\python\python39\lib\subprocess.py:937: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# A subdirectory or file build already exists.
#         1 file(s) copied.

# %%
#https://huggingface.co/datasets/ieuniversity/flirty_or_not/tree/main/data and merged+converted to csv as data.csv in raw/
with open(RAW_DATA + '/data.csv', errors='ignore') as f:
    df = pd.read_csv(f)

# %%
df = df[['texts', 'label']]

# %%
df = df.sample(frac=1)
df = df.dropna()
df
# Out:
#                                                   texts  label
# 1014                Finger yourself until you want more      1
# 1441                               psych sub-specialty?      0
# 329                                                cae?      0
# 2080                  Okay I see you we matched on one!      0
# 1351                  Iâ€™ll say black as my next guess      0
# ...                                                 ...    ...
# 892                                            do we...      1
# 67                  Be prepared to pay my medical bills      1
# 570     Okay Frank is my #1 haha everything is the best      0
# 217                          Only if you want me to be.      1
# 1026  Whatâ€™s the worst and best lines youâ€™ve hea...      1
#
# [2114 rows x 2 columns]

# %%
text_0 = ' '.join(df.loc[df.label == 0]['texts'])
text_1 = ' '.join(df.loc[df.label == 1]['texts'])

wordcloud_0 = WordCloud().generate(text_0)
wordcloud_1 = WordCloud().generate(text_1)

fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,6))

ax1.imshow(wordcloud_0)
ax1.axis("off")
ax1.set_title("Wordcloud for label 0",fontsize=20)

ax2.imshow(wordcloud_1)
ax2.axis("off")
ax2.set_title("Wordcloud for label 1",fontsize=20)

plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(df['texts'], df['label'], stratify=df['label'], 
                                                    test_size=TEST_SIZE, random_state=42)

df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_train.shape[0], df_test.shape[0]
# Out:
# (1479, 635)

# %%
def save_data(df, rootdir):
    with open(rootdir + '/features.txt', 'wt', errors='ignore') as feat_fh, \
        open(rootdir + '/labels.txt', 'wt', errors='ignore') as labl_fh:
        for idx, row in df.iterrows():
            lb = str(row['label']) + '\n'
            ft = row['texts'].replace('\n', ' ').lower() + '\n'
            labl_fh.write(lb)
            feat_fh.write(ft)

# %%
save_data(df_train, TRAIN_DATA)
save_data(df_test, TEST_DATA)
df_test.to_csv(TEST_DATA + '/data_test.csv', index=False)

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 1 {path.join('model','model_CounterVectorizer_NaiveBayesClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 smoothing_param_m=1.0,smoothing_param_p=0.5
# Out:
# Training
# minfrequency = 2
# smoothing_param_m = 1
# smoothing_param_p = 0.5
# No of Rare Words = 1950
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 1 {path.join('model','model_TfidfVectorizer_NaiveBayesClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 smoothing_param_m=1.0,smoothing_param_p=0.5
# Out:
# Training
# minfrequency = 2
# smoothing_param_m = 1
# smoothing_param_p = 0.5
# No of Rare Words = 1950
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 2 {path.join('model','model_CounterVectorizer_LogisticRegressionClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 1950
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 2 {path.join('model','model_TfidfVectorizer_LogisticRegressionClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 1950
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 3 {path.join('model','model_CounterVectorizer_SVCClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 1950
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 3 {path.join('model','model_TfidfVectorizer_SVCClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 1950
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# ...

# %% [raw]
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 4 {path.join('model','model_CounterVectorizer_KNNClassifier.dat')} {path.join('data','train','features.txt')} 1.0 k=3

# %% [raw]
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 4 {path.join('model','model_TfidfVectorizer_KNNClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 k=3

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 5 {path.join('model','model_CounterVectorizer_RandomForestClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 num_trees=50,max_depth=5
# Out:
# Training
# minfrequency = 2
# num_trees = 50
# max_depth = 5
# No of Rare Words = 1950
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 5 {path.join('model','model_TfidfVectorizer_RandomForestClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 num_trees=50,max_depth=5
# Out:
# Training
# minfrequency = 2
# num_trees = 50
# max_depth = 5
# No of Rare Words = 1950
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 1 6 {path.join('model','model_CounterVectorizer_GradientBoostingClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 1950
# Fitting CountVectorizer...
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# ...

# %%
# %%time
# %runshell {MLTEXTCLASSIFIER} f 2 6 {path.join('model','model_TfidfVectorizer_GradientBoostingClassifier.dat')} {path.join('data','train','features.txt')} {path.join('data','train','labels.txt')} 1.0 n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 1950
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# ...
