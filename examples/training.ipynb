# %%
import pandas as pd

# %%
RAW_DATA = './data/raw'
TRAIN_DATA = './data/train'
TEST_DATA = './data/test'
TRAIN_TEST_SPLIT = 0.7

# %%
from subprocess import Popen, PIPE, STDOUT
from IPython.core.magic import register_line_magic

@register_line_magic
def runshell(command):
    with Popen(
        command, stdout=PIPE, shell=True, stderr=STDOUT, bufsize=1, close_fds=True
    ) as process:
        for line in iter(process.stdout.readline, b""):
            print(line.decode("utf-8"), end='')

# %%
# Convert this cell to 'Code' to build mltextclassifier.exe
# %runshell cd .. && mkdir build && cd build && cmake .. >> buildlog.txt 2>&1
# %runshell cd ..\build && cmake --build . --config Release >> buildlog.txt 2>&1
# %runshell copy ..\build\Release\mltextclassifier.exe .
# Out:
# c:\users\rajas.chavadekar\appdata\local\programs\python\python39\lib\subprocess.py:941: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# A subdirectory or file build already exists.
#         1 file(s) copied.

# %%
#https://www.kaggle.com/datasets/abhi8923shriv/sentiment-analysis-dataset?select=train.csv renamed as data.csv in raw/
with open(RAW_DATA + '/data.csv', errors='ignore') as f:
    df = pd.read_csv(f)

# %%
df = df[df.sentiment != 'neutral'][['text', 'sentiment']]

# %%
df['sentiment'] = df['sentiment'].replace({'positive': 1, 'negative': 0})

# %%
df = df.sample(frac=1)

# %%
split_index = int(TRAIN_TEST_SPLIT * df.shape[0])
df_train = df.iloc[:split_index]
df_test = df.iloc[split_index:]

# %%
df_train.shape[0], df_test.shape[0]
# Out:
# (11454, 4909)

# %%
def save_data(df, rootdir):
    with open(rootdir + '/features.txt', 'wt', errors='ignore') as feat_fh, \
        open(rootdir + '/labels.txt', 'wt', errors='ignore') as labl_fh:
        for idx, row in df.iterrows():
            lb = str(row['sentiment']) + '\n'
            ft = row['text'] + '\n'
            labl_fh.write(lb)
            feat_fh.write(ft)
            
save_data(df_train, TRAIN_DATA)
save_data(df_test, TEST_DATA)

# %%
# %%time
# %runshell mltextclassifier.exe f 1 1 model\model_CounterVectorizer_NaiveBayesClassifier.bin data\train\features.txt data\train\labels.txt alpha=1.0
# Out:
# c:\users\rajas.chavadekar\appdata\local\programs\python\python39\lib\subprocess.py:941: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# Training
# alpha = 1
# fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 2 1 model\model_TfidfVectorizer_NaiveBayesClassifier.bin data\train\features.txt data\train\labels.txt alpha=1.0
# Out:
# Training
# alpha = 1
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 1 2 model\model_CounterVectorizer_LogisticRegressionClassifier.bin data\train\features.txt data\train\labels.txt bias=0.0,epochs=10,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# bias = 0
# epochs = 10
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 2 2 model\model_TfidfVectorizer_LogisticRegressionClassifier.bin data\train\features.txt data\train\labels.txt bias=0.0,epochs=10,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# bias = 0
# epochs = 10
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 1 3 model\model_CounterVectorizer_SVCClassifier.bin data\train\features.txt data\train\labels.txt bias=0.0,epochs=10,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# bias = 0
# epochs = 10
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 2 3 model\model_TfidfVectorizer_SVCClassifier.bin data\train\features.txt data\train\labels.txt bias=0.0,epochs=10,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# bias = 0
# epochs = 10
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# ...

# %% [raw]
# %%time
# %runshell mltextclassifier.exe f 1 4 model\model_CounterVectorizer_KNNClassifier.bin data\train\features.txt data\train\labels.txt k=3

# %% [raw]
# %%time
# %runshell mltextclassifier.exe f 2 4 model\model_TfidfVectorizer_KNNClassifier.bin data\train\features.txt data\train\labels.txt k=3

# %%
# %%time
# %runshell mltextclassifier.exe f 1 5 model\model_CounterVectorizer_RandomForestClassifier.bin data\train\features.txt data\train\labels.txt num_trees=50,max_depth=5
# Out:
# Training
# num_trees = 50
# max_depth = 5
# fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 2 5 model\model_TfidfVectorizer_RandomForestClassifier.bin data\train\features.txt data\train\labels.txt num_trees=50,max_depth=5
# Out:
# Training
# num_trees = 50
# max_depth = 5
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 1 6 model\model_CounterVectorizer_GradientBoostingClassifier.bin data\train\features.txt data\train\labels.txt n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# ...

# %%
# %%time
# %runshell mltextclassifier.exe f 2 6 model\model_TfidfVectorizer_GradientBoostingClassifier.bin data\train\features.txt data\train\labels.txt n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# ...
