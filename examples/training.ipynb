# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
RAW_DATA = './data/raw'
TRAIN_DATA = './data/train'
TEST_DATA = './data/test'
TEST_SIZE = 0.3

# %%
from subprocess import Popen, PIPE, STDOUT
from IPython.core.magic import register_line_magic

@register_line_magic
def runshell(command):
    with Popen(
        command, stdout=PIPE, shell=True, stderr=STDOUT, bufsize=1, close_fds=True
    ) as process:
        for line in iter(process.stdout.readline, b""):
            print(line.decode("utf-8"), end='')

# %%
# Convert this cell to 'Code' to build mltextclassifier.exe
# %runshell cd .. && mkdir build && cd build && cmake .. >> buildlog.txt 2>&1
# %runshell cd ..\build && cmake --build . --config Release >> buildlog.txt 2>&1
# %runshell copy ..\build\Release\mltextclassifier.exe .
# Out:
# c:\users\rajas.chavadekar\appdata\local\programs\python\python39\lib\subprocess.py:941: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
#         1 file(s) copied.

# %%
#https://www.kaggle.com/datasets/abhi8923shriv/sentiment-analysis-dataset?select=train.csv renamed as data.csv in raw/
with open(RAW_DATA + '/data.csv', errors='ignore') as f:
    df = pd.read_csv(f)

# %%
df = df[df.sentiment != 'neutral'][['text', 'sentiment']]

# %%
df['sentiment'] = df['sentiment'].replace({'positive': 1, 'negative': 0})

# %%
df = df.sample(frac=1)
df
# Out:
#                                                     text  sentiment
# 21820   http://twitpic.com/4gemf - I can definitely a...          1
# 12926  just got home from a partyyyy. had a good time...          1
# 23885     @ work do not feel like bein in dis **** today          0
# 14690                  says it`s late. Goodnight people!          1
# 5300    - for all dad is doing like this to his son/d...          1
# ...                                                  ...        ...
# 20999             Tonight`s SNL does not dissapoint. LOL          0
# 17400             http://twitpic.com/4w0yj - wow, fancy!          1
# 13010  Earthlink says our modem is dead.  They want m...          0
# 20890  _K Why thank you ver much!  I appreci-****-ate...          1
# 11008  Our jazz band freakin` KICKED ****!! Good job,...          1
#
# [16363 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], stratify=df['sentiment'], 
                                                    test_size=TEST_SIZE, random_state=42)

df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_train.shape[0], df_test.shape[0]
# Out:
# (11454, 4909)

# %%
def save_data(df, rootdir):
    with open(rootdir + '/features.txt', 'wt', errors='ignore') as feat_fh, \
        open(rootdir + '/labels.txt', 'wt', errors='ignore') as labl_fh:
        for idx, row in df.iterrows():
            lb = str(row['sentiment']) + '\n'
            ft = row['text'].lower() + '\n'
            labl_fh.write(lb)
            feat_fh.write(ft)

# %%
save_data(df_train, TRAIN_DATA)
save_data(df_test, TEST_DATA)
df_test.to_csv(TEST_DATA + '/data_test.csv', index=False)

# %%
# %%time
# %runshell mltextclassifier.exe f 1 1 model\model_CounterVectorizer_NaiveBayesClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,smoothing_param_m=1.0,smoothing_param_p=0.5
# Out:
# c:\users\rajas.chavadekar\appdata\local\programs\python\python39\lib\subprocess.py:941: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# Training
# minfrequency = 2
# smoothing_param_m = 1
# smoothing_param_p = 0.5
# No of Rare Words = 15216
# Fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 31.2 ms
# Wall time: 377 ms

# %%
# %%time
# %runshell mltextclassifier.exe f 2 1 model\model_TfidfVectorizer_NaiveBayesClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,smoothing_param_m=1.0,smoothing_param_p=0.5
# Out:
# Training
# minfrequency = 2
# smoothing_param_m = 1
# smoothing_param_p = 0.5
# No of Rare Words = 15216
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 0 ns
# Wall time: 1.47 s

# %%
# %%time
# %runshell mltextclassifier.exe f 1 2 model\model_CounterVectorizer_LogisticRegressionClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15216
# Fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# Epoch 0 Loss: 0.578909
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 0 ns
# Wall time: 4.25 s

# %%
# %%time
# %runshell mltextclassifier.exe f 2 2 model\model_TfidfVectorizer_LogisticRegressionClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15216
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# Epoch 0 Loss: 0.41916
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 4.96 s

# %%
# %%time
# %runshell mltextclassifier.exe f 1 3 model\model_CounterVectorizer_SVCClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15216
# Fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 0 ns
# Wall time: 5.75 s

# %%
# %%time
# %runshell mltextclassifier.exe f 2 3 model\model_TfidfVectorizer_SVCClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,bias=0.0,epochs=15,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# bias = 0
# epochs = 15
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15216
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 15.6 ms
# Wall time: 4.66 s

# %% [raw]
# %%time
# %runshell mltextclassifier.exe f 1 4 model\model_CounterVectorizer_KNNClassifier.dat data\train\features.txt data\train\labels.txt 1.0 k=3

# %% [raw]
# %%time
# %runshell mltextclassifier.exe f 2 4 model\model_TfidfVectorizer_KNNClassifier.dat data\train\features.txt data\train\labels.txt 1.0 k=3

# %%
# %%time
# %runshell mltextclassifier.exe f 1 5 model\model_CounterVectorizer_RandomForestClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,num_trees=50,max_depth=5
# Out:
# Training
# minfrequency = 2
# num_trees = 50
# max_depth = 5
# No of Rare Words = 15216
# Fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 62.5 ms
# Wall time: 1.4 s

# %%
# %%time
# %runshell mltextclassifier.exe f 2 5 model\model_TfidfVectorizer_RandomForestClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,num_trees=50,max_depth=5
# Out:
# Training
# minfrequency = 2
# num_trees = 50
# max_depth = 5
# No of Rare Words = 15216
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 62.5 ms
# Wall time: 3.1 s

# %%
# %%time
# %runshell mltextclassifier.exe f 1 6 model\model_CounterVectorizer_GradientBoostingClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15216
# Fitting CountVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current CountVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 31.2 ms
# Wall time: 4.61 s

# %%
# %%time
# %runshell mltextclassifier.exe f 2 6 model\model_TfidfVectorizer_GradientBoostingClassifier.dat data\train\features.txt data\train\labels.txt 1.0 minfrequency=2,n_trees=50,max_depth=5,learning_rate=0.01,l1_regularization_param=0.001,l2_regularization_param=0.0
# Out:
# Training
# minfrequency = 2
# n_trees = 50
# max_depth = 5
# learning_rate = 0.01
# l1_regularization_param = 0.001
# l2_regularization_param = 0
# No of Rare Words = 15216
# fitting TfidfVectorizer...
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done
#
# ------------------------------
# Current TfidfVectorizer Shape:
# Total unique words: 6710
# Documents in corpus: 11454
# ------------------------------
# Model Saved
# Done
# CPU times: total: 31.2 ms
# Wall time: 3.95 s
